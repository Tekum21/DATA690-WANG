# %%
# Seaborn is a Python Data Visualization Library which is based on Matplotlib,
#Used for ploting Statistiscal graphs,identify trends,relationships and outliers.
#It is easier to idetinfy and understand relationships using statistiscal graphs than using just numbers.

# %%
#Importing/Installing Packages.

# %%
#Intalling/ importing packages
import os #This provide fucntion for the interaction with the operating system.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') #this helps filter uneccesary warnings.

# %%
#1. Loading the Raw Data.

# %%
#loading raw data
#Raw data= data frame(df)
#df=pd.read_csv("Marketing Raw Data.csv")
df=pd.read_csv("Marketing Raw Data.csv")
df
# Out:
#            Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0     9/11/2020    46       34     11        11  2020     Monday       707
# 1    10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2    11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3    12/11/2020    46       34     11        11  2020   Thursday      1726
# 4    13/11/2020    46       34     11        11  2020     Friday      2134
# ..          ...   ...      ...    ...       ...   ...        ...       ...
# 177    5/5/2021    19       60      5        17  2021  Wednesday      1400
# 178    6/5/2021    19       60      5        17  2021   Thursday      2244
# 179    7/5/2021    19       60      5        17  2021     Friday      2023
# 180    8/5/2021    19       60      5        17  2021   Saturday      1483
# 181    9/5/2021    20       61      5        17  2021     Sunday      1303
#
#      Revenue  Marketing Spend           Promo
# ...

# %%
#To print out just the top 5 rows of the dataset.
df.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0   9/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
#To print out just the last 5 rows of the dataset.
df.tail()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 177  5/5/2021    19       60      5        17  2021  Wednesday      1400
# 178  6/5/2021    19       60      5        17  2021   Thursday      2244
# 179  7/5/2021    19       60      5        17  2021     Friday      2023
# 180  8/5/2021    19       60      5        17  2021   Saturday      1483
# 181  9/5/2021    20       61      5        17  2021     Sunday      1303
#
#      Revenue  Marketing Spend          Promo
# 177     7284      1119.600000       No Promo
# 178    13021      2067.888889  Promotion Red
# 179     4587      1450.200000       No Promo
# 180     5927      1121.875000       No Promo
# 181     3861       871.000000       No Promo

# %%
# 2. Line Graph

# %%
#Example 1: Simple one line plot
#Assumimng we to investigate Revenue by Date.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.lineplot(x="Date", y="Revenue",data=df)

# %%
#Assuming we want to invsetigate Revenue by Week_ID
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.lineplot(x="Week_ID", y="Revenue",data=df)
#Note, the error bands show that confidence interval.

# %%
#Example 2-Adding categories
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.lineplot(x='Week_ID',y='Revenue',hue="Promo",data=df,ci=None)

# %%
# By Promo with style
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.lineplot(x="Week_ID",y="Revenue",hue="Promo",style="Promo",markers=True, data=df)

# %%
df.columns
# Out:
# Index(['Date', 'Week', 'Week_ID', 'Month', 'Month_ID', 'Year', 'Day_Name',
#        'Visitors', 'Revenue', 'Marketing Spend', 'Promo'],
#       dtype='object')

# %%
#By investigating Revenue by Month_ID with category Day_Name & style as Promo.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.lineplot(x="Month_ID",y="Revenue",hue="Day_Name",data=df,style="Promo",ci=False)
plt.grid()

# %%
#3. Bar Plots

# %%
#Example1: Total Revenue by Month_ID
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.barplot(x="Month_ID",y="Revenue",data=df,ci=None)
#Notes:
# The bars take the mean of the Revenue by default.
#create the mean of the Revenue of our data frame.
df[["Revenue","Month_ID"]].groupby("Month_ID").agg({'Revenue':'mean'})
# Out:
#                Revenue
# Month_ID
# 11        11255.454545
# 12        11667.806452
# 13         9588.516129
# 14        10683.892857
# 15        10555.354839
# 16        10806.500000
# 17         7636.000000

# %%
#Example 2:
#To create a bar plot of Revenue by Month_ID and using but sum of Monthly Revenue rather than the default mean of monthly revenue:
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.barplot(x="Month_ID",y="Revenue",data=df,ci=None)
df[["Revenue","Month_ID"]].groupby("Month_ID").agg({"Revenue":'sum'})
# Out:
#           Revenue
# Month_ID
# 11         247620
# 12         361702
# 13         297244
# 14         299149
# 15         327216
# 16         324195
# 17          68724

# %%
#Example 3:
#To investigate Revenue(Average)by Month_ID using Promo as category.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.barplot(x="Month_ID",y="Revenue",data=df,ci=None,hue="Promo")

# %%
#Example 4:
#To investigate Revenue(Average)by Month_ID using Promo as category, displaying a horizontal chart and not the regular vertical chart as above.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.barplot(x="Revenue",y="Month_ID",data=df,ci=None,hue="Promo",orient="h")

# %%
#Example 5:
#Changing the color of a bar chart. We simple add an argument specifying the desired color.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.barplot(x="Month_ID",y="Revenue",data=df,ci=None,hue="Promo",color="red")

# %%
#We can as well select a color by using the link (https://htmlcolorcodes.com/color-picker/)
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.barplot(x="Month_ID",y="Revenue",data=df,ci=None,hue="Promo",color="#D733FF")

# %%
#4.Histograms

# %%
#Example 1:
#Investigating the distribution of Revenue.
fig,ax=plt.subplots(figsize=(8,8))
Rev=df["Revenue"].values
ax=sns.distplot(Rev,color="blue")
#Calculating the mean
mean=(df["Revenue"].mean())
print(mean)
#ploting the mean
plt.axvline(mean,color="red",label="Av Revenue")
plt.legend()
plt.grid()
#Notes:It is a right skwed distribution as the mean is to the right of the distribution(not exactly at the middle of the distribution)
# Out:
# 10581.593406593407

# %%
#Example 2:
#Investigating the distribution of the visitors.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.distplot(df['Visitors'],color="#BF33FF") # 0r Visitors=df["Visitors"].values, then ax=sns.displot(Visitors,color="red")
#calculating the mean
mean=df["Visitors"].mean()
print(mean)
#ploting the mean
plt.axvline(mean,color="black",label='Av_Visitors')
plt.legend()
plt.grid()
# Out:
# 1666.7307692307693

# %%
#The distribution of Revenue and Visitors are slightly right skwed distibution since both means are to the right of the distributions.
#In general one can say both distributions are normal distributions.

# %%
# 5 Box Plots
#Similar to a histogram, box plots are used to investigate the distributions of a dataset.

# %%
#Example 1:
#Investigating the distribution of Revenue
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.boxplot(df["Revenue"],color="blue")
#calculating the median val of Revenue
median=df["Revenue"].median()
print(median)
#Notes:
#The middle line of the box represents the median
#The first line of the box is the start Q1(25th percentile) and the end of the box line is Q3(75th percentile) 
#The whiskers (left to right) show the minimum and amximum quartiles.
#The dots to the far right are the outliers.
# Out:
# 9452.0

# %%
df.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0   9/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
# Example 2:
#Investigating the distribution of Revenue by Day_Name
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.boxplot(x=df["Day_Name"],y=df["Revenue"])
#calculating the median val of Revenue
median=df["Revenue"].median()
print(median)
#Notes:
#The day with the highest Revenue is Friday and that with the lowest is Saturday.
# Out:
# 9452.0

# %%
#Example 3
#Investigating the distribution of Revenue by Day_Name using category Promo.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.boxplot(x="Day_Name",y="Revenue",data=df, hue='Promo')
#calculating the median val of Revenue
median=df["Revenue"].median()
print(median)
#Note:
#The distribution of promotion blue is generally higher than the other two Promos.
# Out:
# 9452.0

# %%
#Example 4:Swarmplots
#Investigating the distribution of Revenue by Day_Name, showing all data points-swarmplot
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.boxplot(x="Day_Name",y="Revenue",data=df, color='red')
ax=sns.swarmplot(x="Day_Name",y="Revenue",data=df,color="blue")
#calculating the median val of Revenue
median=df["Revenue"].median()
print(median)
#Notes:
#This gives us a better visualization of where the data is concentrated on each day.
# Out:
# 9452.0

# %%
# Scatter Plots

# %%
#Example 1:
# Displaying the relationship between Markwting Spend and Revenue.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x="Marketing Spend",y="Revenue",data=df, color='red')
plt.grid()
#Notes:
#From the scatter plot, we can see that as we spend more money on marketing, the Revenue increases.

# %%
#Example 2:
#From example bove, we see that there are some points that are a bit further from the distribution
#We can investigate thses points by using a category.
# Displaying the relationship between Markwting Spend and Revenue, using promo as a category.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x="Marketing Spend",y="Revenue",data=df, color='red',hue="Promo",style="Promo")
plt.grid()
#Notes:
# we can see that spending more on marketing by doing more promotions in particular increases revenue.

# %%
#Example 3:
#Investigating the realatioship between Marketing Spend and Revenue using Promo as a category and Visitors as an indicator.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x="Marketing Spend",y="Revenue",data=df, color='red',hue="Promo",style="Promo",size="Visitors",sizes=(20,200))
plt.grid()
#Notes:
#Increasing marketing sepnd on promo increases revenue, 
#also generally increasing promotions leads to increase in the number of visitors as indicated by the increase in the sizes of green sqs.
#We also noticed a few increase in visitors due to high market spend even at a low promo rate as shown by the blue round dots.

# %%
#Example 4:
#Investigating the realatioship between Marketing Spend and Visitors using Day as a category.
fig,ax=plt.subplots(figsize=(8,8))
ax=sns.scatterplot(x="Marketing Spend",y="Visitors",data=df, color='red',hue="Day_Name")
plt.grid()
#Notes:
# This does not show any distinct relataionship.

# %%
#7. Lmplots.
#This is basically a scatter plot having a regression line on it.

# %%
#Example 1:Relationship between Marketing spend and Revenue.
ax=sns.lmplot(x="Marketing Spend",y ="Revenue", data=df, height=8)
plt.grid()
#Notes:
# A linear Regression is a Predictive Statistical Method for modeling a relationship between x(independent varialbe) & y(dependent variable)
#The regression line helps one to predict how much revenue can be generated relative Marketing spend.

# %%
#Example 2:Relationship between Marketing spend and Revenu- changing color, hue & style
ax=sns.lmplot(x="Marketing Spend",y ="Revenue", data=df, height=8, hue="Promo")
plt.grid()
#Notes:

# %%
#Example 3:
# Multiple scatter plots
#Relationship between Marketing spend and Revenu- changing color, hue & style
ax=sns.lmplot(x="Marketing Spend",y ="Revenue", data=df, height=5, col="Promo")
plt.grid()

# %%
#Example 3:
# Multiple scatter plots
#Relationship between Marketing spend and Revenu- changing color, hue & style
ax=sns.lmplot(x="Marketing Spend",y ="Revenue", data=df, height=5, col="Promo",line_kws={"color":'red'},scatter_kws={'color':"#BF33FF"})
plt.grid()

# %%
#8.Subplots

# %%
#Subplots are used when you want to create multiple plots close to each other.
#Step 1: Set up a Matplotlib figure
fig,axis=plt.subplots(2,2,figsize=(12,7))
a=df["Revenue"].values
b=df["Visitors"].values
c=df['Marketing Spend'].values
#plot 1
ax=sns.distplot(a,color="blue",ax=axis[0,0])
#plot 2
ax=sns.scatterplot(x=a,y=b,hue="Promo",style="Promo", ax=axis[1,0],data=df)
#plot 3
ax=sns.lineplot(x=c,y=b,data=df,hue='Promo',ax=axis[1,1])
#plot 4
ax=sns.distplot(df["Month_ID"],color="red",ax=axis[0,1])

# %%
#9.Pairplots

# %%
#Exapmle 1-Running on all dataframe-color green
g=sns.pairplot(df,plot_kws={'color':"green"})
#This actually plots every varaible in the dataframe.

# %%
df.columns
# Out:
# Index(['Date', 'Week', 'Week_ID', 'Month', 'Month_ID', 'Year', 'Day_Name',
#        'Visitors', 'Revenue', 'Marketing Spend', 'Promo'],
#       dtype='object')

# %%
#Example 2
#Here we specify, the varaibles we are interested in from above by selecting numeric columns.
g=sns.pairplot(df[['Visitors', 'Revenue', 'Marketing Spend']],plot_kws={'color':"green"},height=6,kind="reg")

# %%
#Example 3
#Running on selected columns and adding hue=Promo
g=sns.pairplot(df[['Visitors', 'Revenue', 'Marketing Spend','Promo']],height=6,hue="Promo")

# %%
#Example 4
#Adding a regression line on pairplota.
g=sns.pairplot(df[['Visitors', 'Revenue', 'Marketing Spend','Promo']],height=7,kind="reg",hue="Promo")

# %%
#10. Jointplots

# %%
#Jointplots are used to investigate the relationship between two variables at the same time using two axses.
#Example 1
# Revenue Vs Marketing Spend 
ax=sns.jointplot(x="Marketing Spend",y="Revenue", height=7,data=df,kind="reg",color="green")

# %%
#11. Heat Map

# %%
#First we are going to create a dataset that we will display on the heat map-we will use a correlation dataset
#.corr() is used to find all the pairwise correlation of all the columns of the dataframe. Any null values are automatically left out.
#the .corr() compairs the values of the variables between 0-1.
# closser to -1(negative corr), +1(+ corr)
#The closer to 1,or -1 the better.As one variable increse, the other also tends to increase/decrease.
#We will can correlate only numerical values and not categorical values.

# %%
#Example 1
#Running a heat map for data frame pc
pc=df[['Visitors','Revenue','Marketing Spend']].corr()
pc
# Out:
#                  Visitors   Revenue  Marketing Spend
# Visitors         1.000000  0.573842         0.824810
# Revenue          0.573842  1.000000         0.790425
# Marketing Spend  0.824810  0.790425         1.000000

# %%
hm=sns.heatmap(pc)

# %%
#the scale starts from somewhere around 0.57, this is because the starting point is always a value closser to the lowest value of the corr dataframe (pc)
#The more darker the color, the lower the pearson corr is between the variables, and the lighter the color is, the stronger the corr.

# %%
#Adding annotations to the heat map and inscreasing the size
hm=sns.heatmap(pc, annot=True, annot_kws={"size":30})

# %%
#from our heatmap, we see that Revenue is not affected by Visitors buth rather, the more Marketing Spend, the more Revenue generated.

# %%
# we ca change the columns labels by:
col=['Visitors Pc','Revenue Pc','Marketing Spend Pc']
hm=sns.heatmap(pc,annot=True, annot_kws={"size":30},xticklabels=col,yticklabels=col)

# %%
#Example 2
#how to change the heat map for pc-cmap (this is basically changing the coloring)
col=['Visitors Pc','Revenue Pc','Marketing Spend Pc']
hm=sns.heatmap(pc,annot=True, annot_kws={"size":30},xticklabels=col,yticklabels=col,cmap="Greens")

# %%
col=['Visitors Pc','Revenue Pc','Marketing Spend Pc']
hm=sns.heatmap(pc,annot=True, annot_kws={"size":30},xticklabels=col,yticklabels=col,cmap="BuPu")

# %%
col=['Visitors Pc','Revenue Pc','Marketing Spend Pc']
hm=sns.heatmap(pc,annot=True, annot_kws={"size":30},xticklabels=col,yticklabels=col,cmap="Blues")

# %%
col=['Visitors Pc','Revenue Pc','Marketing Spend Pc']
hm=sns.heatmap(pc,annot=True, annot_kws={"size":30},xticklabels=col,yticklabels=col,cmap="YlGnBu")
