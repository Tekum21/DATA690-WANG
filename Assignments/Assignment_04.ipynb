# %%
# <1> 
# Import libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("MERGED2017_18_PP.csv")
df
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# ...

# %%
df.columns
# Out:
# Index(['OPEID', 'OPEID6', 'INSTNM', 'CITY', 'ZIP', 'ADM_RATE', 'UGDS',
#        'TUITIONFEE_IN'],
#       dtype='object')

# %%
# <2>
# load the 2017-2018 school year file "MERGED2017_18_PP.csv" 
# Don't include all columns - too many and take up computer resources (computeing power and memory)
# Only load the following 10 columns should be loaded:
# UNITID: 
# OPEID:              
# OPEID6:            
# INSTNM:          
# CITY:                      
# ZIP:               
# ADM_RATE:           
# UGDS:              
# TUITIONFEE_IN:      

df=df[['UNITID','OPEID','OPEID6','INSTNM','CITY','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN']]
df
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# ...

# %%
df.set_index('UNITID',inplace=True)
df
# Out:
#             OPEID  OPEID6                                             INSTNM  \
# UNITID
# 100654     100200    1002                           Alabama A & M University
# 100663     105200    1052                University of Alabama at Birmingham
# 100690    2503400   25034                                 Amridge University
# 100706     105500    1055                University of Alabama in Huntsville
# 100724     100500    1005                           Alabama State University
# ...           ...     ...                                                ...
# 48312404   108163    1081                   Arizona State University at Yuma
# 48387801  4223701   42237  Bay Area Medical Academy - San Jose Satellite ...
# 48400201  4228101   42281                        High Desert Medical College
# 48778201  4221501   42215                                       BCI - Malden
# 49005401  4182601   41826          Health Career Institute- Lauderdale Lakes
#
# ...

# %%
# <3>
# Load the scorecard file Most-Recent-Cohorts-Scorecard-Elements.csv from the link:
# https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-Scorecard-Elements.csv
# This file has thre median earnings which is not present in the previous file
# Only load the two columns:
# UNITID - This column is the unique identity for each college and will be used to join with the previous file
# MD_EARN_WNE_P10  - This column has the median earnings
df2=pd.read_csv('Most-Recent-Cohorts-All-Data-Elements.csv')

# %%
df2=df2[['UNITID',"MD_EARN_WNE_P10"]]
df2
# Out:
#         UNITID MD_EARN_WNE_P10
# 0       100654           31000
# 1       100663           41200
# 2       100690           39600
# 3       100706           46700
# 4       100724           27700
# ...        ...             ...
# 7107  48312404             NaN
# 7108  48387801             NaN
# 7109  48400201             NaN
# 7110  48778201             NaN
# 7111  49005401             NaN
#
# [7112 rows x 2 columns]

# %%
df2.set_index("UNITID",inplace=True)
df2
# Out:
#          MD_EARN_WNE_P10
# UNITID
# 100654             31000
# 100663             41200
# 100690             39600
# 100706             46700
# 100724             27700
# ...                  ...
# 48312404             NaN
# 48387801             NaN
# 48400201             NaN
# 48778201             NaN
# 49005401             NaN
#
# [7112 rows x 1 columns]

# %%
# <4> 
# Explore this file - number of colleges, head/tail/sample etc.
# Notice this file has different number of colleges from the previous file
# This indicate they are not identical and they overlap (they don't contain the same set of colleges)
#(Write code here)
df2.shape
# Out:
# (7112, 1)

# %%
df2.head(10)
# Out:
#        MD_EARN_WNE_P10
# UNITID
# 100654           31000
# 100663           41200
# 100690           39600
# 100706           46700
# 100724           27700
# 100751           44500
# 100760           27700
# 100812           38700
# 100830           33300
# 100858           48800

# %%
df2.tail(10)
# Out:
#          MD_EARN_WNE_P10
# UNITID
# 48154401             NaN
# 48305401             NaN
# 48312401             NaN
# 48312402             NaN
# 48312403             NaN
# 48312404             NaN
# 48387801             NaN
# 48400201             NaN
# 48778201             NaN
# 49005401             NaN

# %%
df2.sort_values('MD_EARN_WNE_P10').head(10)
# Out:
#        MD_EARN_WNE_P10
# UNITID
# 228635          102100
# 214564          102500
# 166683          104700
# 112525          106100
# 423643          107700
# 143853          107700
# 413626           10800
# 105701           10800
# 189501          108800
# 122296          111100

# %%
df2.sample(10)
# Out:
#          MD_EARN_WNE_P10
# UNITID
# 191719             37100
# 238032             45800
# 172422             22900
# 204909             45300
# 127820             31300
# 460543             46500
# 149231             43000
# 461528               NaN
# 235316             56100
# 15631001           18000

# %%
df2.fillna(0)
# Out:
#          MD_EARN_WNE_P10
# UNITID
# 100654             31000
# 100663             41200
# 100690             39600
# 100706             46700
# 100724             27700
# ...                  ...
# 48312404               0
# 48387801               0
# 48400201               0
# 48778201               0
# 49005401               0
#
# [7112 rows x 1 columns]

# %%
# <5>
#Join the two files together to produce a third file which contain all the columns and all colleges that are common to both files
df3 = pd.merge(df,df2, on='UNITID',how="inner")

# %%
#Read Headers
df3.columns
# Out:
# Index(['OPEID', 'OPEID6', 'INSTNM', 'CITY', 'ZIP', 'ADM_RATE', 'UGDS',
#        'TUITIONFEE_IN', 'MD_EARN_WNE_P10'],
#       dtype='object')

# %%
df3.head(4)
# Out:
#           OPEID  OPEID6                               INSTNM        CITY  \
# UNITID
# 100654   100200    1002             Alabama A & M University      Normal
# 100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 100690  2503400   25034                   Amridge University  Montgomery
# 100706   105500    1055  University of Alabama in Huntsville  Huntsville
#
#                ZIP  ADM_RATE     UGDS  TUITIONFEE_IN MD_EARN_WNE_P10
# UNITID
# 100654       35762    0.9027   4824.0         9857.0           31000
# 100663  35294-0110    0.9181  12866.0         8328.0           41200
# 100690  36117-3553       NaN    322.0         6900.0           39600
# 100706       35899    0.8123   6917.0        10280.0           46700

# %%
# <7>
# Find out the top 100 colleges that are hardest to get in (Top 100) from this
df4=df3.sort_values("ADM_RATE").head(100)
df4
# Out:
#           OPEID  OPEID6                                             INSTNM  \
# UNITID
# 491288   389600    3896             University of Wisconsin-Milwaukee Flex
# 448309   159101    1591  Shorter University-College of Adult & Professi...
# 480912  4219700   42197       Gemini School of Visual Arts & Communication
# 211635   653400    6534                         Citizens School of Nursing
# 211893   325100    3251                          Curtis Institute of Music
# ...         ...     ...                                                ...
# 215594   656500    6565         Reading Hospital School of Health Sciences
# 486123  4158800   41588                                    Theatre of Arts
# 133979   148600    1486                        Florida Memorial University
# 234076   374500    3745                 University of Virginia-Main Campus
# 167358   219900    2199                            Northeastern University
#
# ...

# %%
#to have the total number of rows and columns in df3:
df3.shape
# Out:
# (7112, 9)

# %%
#To remove all columns containing "PrivacySuppressed":
df4 = df3[df3["MD_EARN_WNE_P10"] != "PrivacySuppressed"]
df4
# Out:
#             OPEID  OPEID6                                             INSTNM  \
# UNITID
# 100654     100200    1002                           Alabama A & M University
# 100663     105200    1052                University of Alabama at Birmingham
# 100690    2503400   25034                                 Amridge University
# 100706     105500    1055                University of Alabama in Huntsville
# 100724     100500    1005                           Alabama State University
# ...           ...     ...                                                ...
# 48312404   108163    1081                   Arizona State University at Yuma
# 48387801  4223701   42237  Bay Area Medical Academy - San Jose Satellite ...
# 48400201  4228101   42281                        High Desert Medical College
# 48778201  4221501   42215                                       BCI - Malden
# 49005401  4182601   41826          Health Career Institute- Lauderdale Lakes
#
# ...

# %%
#To drop all non values in df4:
df4 = df4.dropna()
df4
# Out:
#           OPEID  OPEID6                               INSTNM         CITY  \
# UNITID
# 100654   100200    1002             Alabama A & M University       Normal
# 100663   105200    1052  University of Alabama at Birmingham   Birmingham
# 100706   105500    1055  University of Alabama in Huntsville   Huntsville
# 100724   100500    1005             Alabama State University   Montgomery
# 100751   105100    1051            The University of Alabama   Tuscaloosa
# ...         ...     ...                                  ...          ...
# 482680   158500    1585          University of North Georgia    Dahlonega
# 483124   108159    1081     Arizona State University-Skysong   Scottsdale
# 484473   153500    1535         University of Florida-Online  Gainesville
# 484905  4242100   42421  University of North Texas at Dallas       Dallas
# 485272  3698308   36983          West Coast University-Miami        Doral
#
#                ZIP  ADM_RATE     UGDS  TUITIONFEE_IN MD_EARN_WNE_P10
# ...

# %%
#To remove all colunms that contain 'PrivacySuppressed':
df4.loc[df4["MD_EARN_WNE_P10"].str.contains("PrivacySuppressed")]
df4
# Out:
#           OPEID  OPEID6                               INSTNM         CITY  \
# UNITID
# 100654   100200    1002             Alabama A & M University       Normal
# 100663   105200    1052  University of Alabama at Birmingham   Birmingham
# 100706   105500    1055  University of Alabama in Huntsville   Huntsville
# 100724   100500    1005             Alabama State University   Montgomery
# 100751   105100    1051            The University of Alabama   Tuscaloosa
# ...         ...     ...                                  ...          ...
# 482680   158500    1585          University of North Georgia    Dahlonega
# 483124   108159    1081     Arizona State University-Skysong   Scottsdale
# 484473   153500    1535         University of Florida-Online  Gainesville
# 484905  4242100   42421  University of North Texas at Dallas       Dallas
# 485272  3698308   36983          West Coast University-Miami        Doral
#
#                ZIP  ADM_RATE     UGDS  TUITIONFEE_IN MD_EARN_WNE_P10
# ...

# %%
# <8>
# Display the summary statistics of the in-state tuitions of the top 100 colleges that are hardest to get in
df4['TUITIONFEE_IN'].describe()
# Out:
# count     1688.000000
# mean     23391.104265
# std      14092.352844
# min        480.000000
# 25%      10413.500000
# 50%      20949.000000
# 75%      33730.000000
# max      57208.000000
# Name: TUITIONFEE_IN, dtype: float64

# %%
# Display the histogram of the in-state tuitions of the top 100 colleges that are hardest to get in
bins=[5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000]
df4.hist("TUITIONFEE_IN",figsize=(10,10),bins=bins,edgecolor="black")
Average_Tuition=23400
color='red'
plt.axvline(Average_Tuition,color=color,label="Avg_Tuition")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Diding the hist into bins gives a clear picture of the number of institutions within a given tuition fee range.
#0 inst with tuition fee<5000
#About 375 schools with tuition fee>=5000<=10000
#About 240 schools with tuition fee>=10000<=15000
#.....
#Just about 10 schools with tuiton fee>=55000<=60000
#To be able to see number of schools within each bin well, we add the argument (log="True") into our plt;
#df4.hist("TUITIONFEE_IN",figsize=(10,10),bins=bins,edgecolor="black",log="True")

# %%
# <10>
# Display the summary statistics of the earning potentials of the top 100 colleges that are hardest to get
df4.describe()
# Out:
#               OPEID        OPEID6     ADM_RATE          UGDS  TUITIONFEE_IN
# count  1.688000e+03   1688.000000  1688.000000   1688.000000    1688.000000
# mean   4.980075e+05   4980.068128     0.671984   4857.359597   23391.104265
# std    6.601096e+05   6601.092035     0.203163   7368.009929   14092.352844
# min    1.002000e+05   1002.000000     0.000000      4.000000     480.000000
# 25%    2.007750e+05   2007.750000     0.544875    911.750000   10413.500000
# 50%    2.936500e+05   2936.500000     0.696350   1955.500000   20949.000000
# 75%    3.729000e+05   3729.000000     0.822375   5329.000000   33730.000000
# max    4.254200e+06  42542.000000     1.000000  68214.000000   57208.000000

# %%
df4["MD_EARN_WNE_P10"] =  df4["MD_EARN_WNE_P10"] .astype('float64')
df4
# Out:
#           OPEID  OPEID6                               INSTNM         CITY  \
# UNITID
# 100654   100200    1002             Alabama A & M University       Normal
# 100663   105200    1052  University of Alabama at Birmingham   Birmingham
# 100706   105500    1055  University of Alabama in Huntsville   Huntsville
# 100724   100500    1005             Alabama State University   Montgomery
# 100751   105100    1051            The University of Alabama   Tuscaloosa
# ...         ...     ...                                  ...          ...
# 482680   158500    1585          University of North Georgia    Dahlonega
# 483124   108159    1081     Arizona State University-Skysong   Scottsdale
# 484473   153500    1535         University of Florida-Online  Gainesville
# 484905  4242100   42421  University of North Texas at Dallas       Dallas
# 485272  3698308   36983          West Coast University-Miami        Doral
#
#                ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MD_EARN_WNE_P10
# ...

# %%
# <11>
# Display the histogram of the earning potentials of the top 100 colleges that are hardest to get in
#(Write code here)
bins=[20000,30000,40000,50000,60000,70000,80000,90000,100000,110000,120000]
df4.hist("MD_EARN_WNE_P10",figsize=(10,10),log="True",bins=bins,edgecolor="black")
plt.show()

# %%
#Scatter plot of in-state tuition and admission rate
y=df4['TUITIONFEE_IN']
x=df4['ADM_RATE']
fig, ax=plt.subplots(figsize=(10,10))
plt.xlabel('ADM_RATE'),plt.ylabel('TUITIONFEE_IN')
plt.scatter(x,y)

# %%
# <12>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Pandas

df4.plot.scatter(x="TUITIONFEE_IN", y="MD_EARN_WNE_P10",marker="X",s=30,figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# <13>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Matplotlib
fig, ax = plt.subplots(figsize=(10,10))  
ax.scatter(df4['TUITIONFEE_IN'][0:100],df4['MD_EARN_WNE_P10'][0:100],color='green')
ax.set_title('TUITIONFEE_IN Vs MD_EARN_WNE_P10', fontsize=14)
ax.set_xlabel('MD_EARN_WNE_P10', fontsize=14,color='red')
ax.set_ylabel('TUITIONFEE_IN', fontsize=14)
    
ax.grid(True)

# %%
# <14>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Seaborn
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,15))
sns.scatterplot(x='TUITIONFEE_IN', y='MD_EARN_WNE_P10',edgecolor='black',linewidth=1,alpha=0.75 ,data=df4)

# %%
df4.plot(x='TUITIONFEE_IN', y='MD_EARN_WNE_P10',figsize=(10,10))

# %%
# <15> 
# Your observation/conclusion of the scatter plot (use the following Markdown cell)
"""As seen from the scattered plot, increase in tuition fee does not indicate an increase in Medain wage"""

# %% [markdown]
# #### Based on my observation of the scatter plot,
# #### blah, blah (are the two variable related? how?, etc)
# #### blah, blah
# #### ...
# #### blah, blah
