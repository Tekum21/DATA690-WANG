# %% [markdown]
# <a href="https://colab.research.google.com/github/Tekum21/DATA690-WANG/blob/master/Copy_of_wordCount_Python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple Word count using Python
# #we will use as essay as input

# %%
import os
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

TEXT_FILE="against-interpretation.txt"

# %%
# !ls # OR [".config","against-interpretation.txt","sample_data"]
# Out:
# against-interpretation.txt  sample_data

# %%
# Read the file and parse it to great a list of lower-case words
# Some words has "\n", ",", or "." at the end. 
# These extra characters are to be removed.
# Also, exclude the words that are considered STOPWORDS

TEXT_FILE ="against-interpretation.txt"

with open(TEXT_FILE,encoding ='utf-8', errors ='ignore') as file:
  susan_lines = file.readlines()
  
susan_words = []
for line in susan_lines:
    for word in line.split(" "):
        word = word.strip().rstrip("\n").rstrip(".").rstrip(",").lower()
        if word in STOPWORDS:                  # ignore the STOPWORDS
            continue
        else:
            susan_words.append(word)

susan_words[:10]         # Display the first 10 words
# Out:
# ['content',
#  'glimpse',
#  'something',
#  'encounter',
#  'flash',
#  'tinyvery',
#  'tiny',
#  'content',
#  'william',
#  'de']

# %%
list(STOPWORDS)
# Out:
# ['by',
#  'their',
#  "can't",
#  'itself',
#  'does',
#  'me',
#  "she'd",
#  'this',
#  "you'll",
#  'only',
#  'at',
#  "who's",
#  'own',
#  "hasn't",
#  'out',
#  'into',
#  'here',
#  'no',
#  'very',
#  'had',
#  "it's",
#  'these',
#  "wasn't",
#  'few',
#  'hers',
#  "you've",
#  'did',
#  "he'd",
#  "they're",
#  'ours',
#  'ourselves',
#  'if',
#  'otherwise',
#  'can',
#  "he's",
#  'is',
#  "there's",
#  'but',
#  'same',
#  'him',
#  'having',
#  "isn't",
#  "mustn't",
#  'not',
#  "where's",
#  'some',
#  "weren't",
#  'be',
#  "you'd",
#  "wouldn't",
#  'each',
#  'then',
#  'there',
#  "aren't",
#  'who',
#  'an',
#  'more',
#  'too',
#  'than',
#  "they'll",
#  'against',
#  'during',
#  "we'll",
#  'themselves',
#  'nor',
#  'myself',
#  "how's",
#  'so',
#  'we',
#  "let's",
#  'off',
#  'i',
#  'her',
#  'theirs',
#  'until',
#  "we'd",
#  'she',
#  "i'm",
#  'how',
#  'most',
#  "didn't",
#  'under',
#  "they've",
#  'just',
#  'whom',
#  'his',
#  'www',
#  'were',
#  'on',
#  'over',
#  "why's",
#  'been',
#  'http',
#  'both',
#  "don't",
#  'since',
#  'which',
#  'your',
#  'where',
#  'and',
#  "she's",
#  'other',
#  'could',
#  "haven't",
#  "she'll",
#  'are',
#  'doing',
#  'he',
#  'himself',
#  'between',
#  'cannot',
#  'get',
#  'above',
#  'while',
#  'would',
#  'our',
#  'else',
#  "when's",
#  'them',
#  'r',
#  'further',
#  'when',
#  'or',
#  "shouldn't",
#  'shall',
#  'the',
#  'for',
#  "we've",
#  "they'd",
#  'why',
#  'what',
#  'ought',
#  'being',
#  "doesn't",
#  "i'd",
#  'have',
#  'it',
#  'do',
#  "here's",
#  'from',
#  "i'll",
#  'like',
#  'yourself',
#  "hadn't",
#  'again',
#  'down',
#  'however',
#  'those',
#  'com',
#  'herself',
#  'with',
#  'my',
#  'should',
#  "i've",
#  'once',
#  "we're",
#  "what's",
#  'before',
#  'also',
#  "won't",
#  'of',
#  "shan't",
#  'any',
#  'to',
#  'after',
#  'because',
#  'has',
#  'am',
#  'up',
#  'you',
#  "he'll",
#  'in',
#  'they',
#  'yourselves',
#  'that',
#  "that's",
#  'about',
#  "you're",
#  "couldn't",
#  'its',
#  'all',
#  'a',
#  'ever',
#  'k',
#  'was',
#  'as',
#  'through',
#  'yours',
#  'such',
#  'below']

# %% [markdown]
# Performing word count and displaying top 10 frequent words.

# %%
wordCounts_dict = {} # We start by creating an empty dict.
for word in susan_words:
  if word in wordCounts_dict.keys():
     wordCounts_dict[word]=wordCounts_dict[word]+1 # increase value by 1
  else:
    wordCounts_dict[word]=1                        # add a new value pair
wordCounts_dict
# Out:
# {'content': 28,
#  'glimpse': 1,
#  'something': 9,
#  'encounter': 1,
#  'flash': 1,
#  'tinyvery': 1,
#  'tiny': 1,
#  'william': 1,
#  'de': 1,
#  'kooning': 1,
#  'interview': 1,
#  'shallow': 1,
#  'people': 4,
#  'judge': 1,
#  'appearances': 2,
#  'mystery': 1,
#  'world': 8,
#  'visible': 2,
#  'invisible': 1,
#  'oscar': 1,
#  'wilde': 1,
#  'letter': 1,
#  'interpretation': 42,
#  'susan': 1,
#  'sontag': 1,
#  'earliest': 2,
#  'experience': 4,
#  'art': 71,
#  'must': 8,
#  'incantatory': 1,
#  'magical;': 1,
#  'instrument': 1,
#  'ritual': 1,
#  '(cf': 1,
#  'paintings': 1,
#  'caves': 1,
#  'lascaux': 1,
#  'altamira': 1,
#  'niaux': 1,
#  'la': 1,
#  'pasiega': 1,
#  'etc.)': 2,
#  'theory': 13,
#  'greek': 3,
#  'philosophers': 1,
#  'proposed': 2,
#  'mimesis': 3,
#  'imitation': 3,
#  'reality': 2,
#  'point': 1,
#  'peculiar': 1,
#  'question': 3,
#  'value': 5,
#  'arose': 1,
#  'mimetic': 6,
#  'terms': 2,
#  'challenges': 1,
#  'justify': 2,
#  'plato': 3,
#  'seems': 3,
#  'done': 2,
#  'order': 4,
#  'rule': 1,
#  'dubious': 2,
#  'considered': 1,
#  'ordinary': 2,
#  'material': 2,
#  'things': 2,
#  'objects': 1,
#  'imitations': 1,
#  'transcendent': 1,
#  'forms': 4,
#  'structures': 1,
#  'even': 7,
#  'best': 4,
#  'painting': 6,
#  'bed': 2,
#  'particularly': 3,
#  'useful': 3,
#  '(the': 5,
#  'good': 4,
#  'sleep': 1,
#  'strict': 1,
#  'sense': 8,
#  'true': 4,
#  'aristotles': 1,
#  'arguments': 1,
#  'defense': 5,
#  'really': 10,
#  'challenge': 1,
#  'platos': 2,
#  'view': 5,
#  'elaborate': 3,
#  'trompe': 1,
#  'loeil': 1,
#  'therefore': 1,
#  'lie': 2,
#  'dispute': 1,
#  'idea': 8,
#  'useless': 1,
#  'certain': 5,
#  'according': 2,
#  'aristotle': 3,
#  'form': 17,
#  'therapy': 1,
#  'counters': 1,
#  'medicinally': 1,
#  'arouses': 1,
#  'purges': 1,
#  'dangerous': 1,
#  'emotions': 1,
#  'goes': 2,
#  'hand': 2,
#  'assumption': 1,
#  'always': 5,
#  'figurative': 2,
#  'advocates': 1,
#  '2': 2,
#  'need': 5,
#  'close': 1,
#  'eyes': 2,
#  'decorative': 2,
#  'abstract': 3,
#  'fallacy': 1,
#  'necessarily': 1,
#  'realism': 1,
#  'modified': 1,
#  'scrapped': 1,
#  'without': 4,
#  'moving': 1,
#  'outside': 1,
#  'problems': 2,
#  'delimited': 1,
#  'fact': 3,
#  'western': 3,
#  'consciousness': 3,
#  'reflection': 1,
#  'upon': 6,
#  'remained': 1,
#  'within': 3,
#  'confines': 1,
#  'staked': 1,
#  'representation': 2,
#  'beyond': 1,
#  'given': 2,
#  'works': 14,
#  'artbecomes': 1,
#  'problematic': 1,
#  'gives': 3,
#  'birth': 1,
#  'odd': 1,
#  'vision': 1,
#  'learned': 2,
#  'call': 2,
#  'separated': 1,
#  'well-intentioned': 1,
#  'move': 3,
#  'makes': 3,
#  'essential': 1,
#  'accessory': 1,
#  'modern': 12,
#  'times': 1,
#  'artists': 2,
#  'critics': 2,
#  'discarded': 2,
#  'outer': 1,
#  'favor': 1,
#  'subjective': 1,
#  'expression': 1,
#  'main': 1,
#  'feature': 2,
#  'persists': 1,
#  'whether': 2,
#  'conceive': 1,
#  'work': 24,
#  'model': 2,
#  'picture': 2,
#  '(art': 2,
#  'reality)': 1,
#  'statement': 3,
#  'artist)': 1,
#  'still': 5,
#  'comes': 1,
#  'first': 3,
#  'may': 12,
#  'changed': 1,
#  'now': 12,
#  'less': 6,
#  'lucidly': 1,
#  'realistic': 2,
#  'assumed': 1,
#  'usually': 1,
#  'put': 2,
#  'today': 5,
#  'definition': 1,
#  'says': 3,
#  '(what': 1,
#  'x': 5,
#  'saying': 2,
#  'trying': 2,
#  'say': 1,
#  'said': 4,
#  'etc.': 1,
#  'none': 1,
#  'us': 7,
#  'retrieve': 1,
#  'innocence': 1,
#  'knew': 2,
#  'one': 11,
#  'ask': 1,
#  '(or': 1,
#  'thought': 4,
#  'knew)': 1,
#  'end': 1,
#  'stuck': 1,
#  'task': 6,
#  'defending': 2,
#  'quarrel': 1,
#  'another': 5,
#  'means': 7,
#  'indeed': 3,
#  'obligation': 1,
#  'overthrow': 1,
#  'justifying': 1,
#  'becomes': 2,
#  'obtuse': 1,
#  'onerous': 1,
#  'insensitive': 1,
#  'contemporary': 3,
#  'needs': 1,
#  'practice': 1,
#  'case': 4,
#  'whatever': 1,
#  'past': 2,
#  'mainly': 2,
#  'hindrance': 1,
#  'nuisance': 1,
#  'subtle': 2,
#  'philistinism': 2,
#  'though': 2,
#  'actual': 1,
#  'developments': 1,
#  'many': 2,
#  'arts': 7,
#  'seem': 2,
#  'leading': 1,
#  'away': 4,
#  'primarily': 2,
#  'exerts': 1,
#  'extraordinary': 1,
#  'hegemony': 1,
#  'want': 2,
#  'suggest': 2,
#  'perpetuated': 1,
#  'guise': 1,
#  'way': 4,
#  'encountering': 1,
#  'thoroughly': 1,
#  'ingrained': 1,
#  'among': 3,
#  'take': 1,
#  'seriously': 1,
#  'overemphasis': 1,
#  'entails': 1,
#  '': 5,
#  '3': 2,
#  'perennial': 1,
#  'never': 1,
#  'consummated': 1,
#  'project': 4,
#  'conversely': 1,
#  'habit': 1,
#  'approaching': 1,
#  'interpret': 7,
#  'sustains': 1,
#  'fancy': 1,
#  'thing': 3,
#  'course': 4,
#  'dont': 5,
#  'mean': 3,
#  'broadest': 1,
#  'nietzsche': 1,
#  '(rightly)': 1,
#  'facts': 1,
#  'interpretations': 5,
#  'conscious': 1,
#  'act': 2,
#  'mind': 2,
#  'illustrates': 1,
#  'code': 1,
#  'rules': 2,
#  'directed': 1,
#  'plucking': 1,
#  'set': 2,
#  'elements': 2,
#  'y': 2,
#  'z': 2,
#  'forth)': 1,
#  'whole': 1,
#  'virtually': 1,
#  'translation': 1,
#  'interpreter': 2,
#  'look': 2,
#  'see': 5,
#  'meansa?': 1,
#  'b?': 1,
#  'c?': 1,
#  'situation': 3,
#  'prompt': 1,
#  'curious': 1,
#  'transforming': 1,
#  'text?': 1,
#  'history': 1,
#  'materials': 1,
#  'answer': 1,
#  'appears': 2,
#  'culture': 6,
#  'late': 1,
#  'classical': 2,
#  'antiquity': 1,
#  'power': 3,
#  'credibility': 1,
#  'myth': 1,
#  'broken': 1,
#  'introduced': 1,
#  'scientific': 1,
#  'enlightenment': 1,
#  'haunts': 1,
#  'post-mythic': 1,
#  'consciousnessthat': 1,
#  'seemliness': 1,
#  'religious': 2,
#  'symbols': 1,
#  'asked': 1,
#  'ancient': 2,
#  'texts': 3,
#  'pristine': 1,
#  'longer': 1,
#  'acceptable': 1,
#  'summoned': 1,
#  'reconcile': 1,
#  'demands': 2,
#  'thus': 4,
#  'stoics': 1,
#  'accord': 1,
#  'gods': 1,
#  'moral': 1,
#  'allegorized': 1,
#  'rude': 1,
#  'features': 1,
#  'zeus': 2,
#  'boisterous': 1,
#  'clan': 1,
#  'homers': 1,
#  'epics': 1,
#  'homer': 1,
#  'designated': 1,
#  'adultery': 1,
#  'leto': 1,
#  'explained': 1,
#  'union': 1,
#  'wisdom': 1,
#  'vein': 1,
#  'philo': 2,
#  'alexandria': 1,
#  'interpreted': 2,
#  'literal': 2,
#  'historical': 2,
#  'narratives': 1,
#  'hebrew': 1,
#  'bible': 1,
#  'spiritual': 2,
#  'paradigms': 1,
#  'story': 4,
#  'exodus': 1,
#  'egypt': 1,
#  'wandering': 1,
#  'desert': 1,
#  'forty': 1,
#  'years': 1,
#  'entry': 1,
#  'promised': 1,
#  'land': 1,
#  'allegory': 5,
#  'individual': 2,
#  'souls': 1,
#  'emancipation': 1,
#  'tribulations': 1,
#  'final': 1,
#  'deliverance': 1,
#  'presupposes': 1,
#  'discrepancy': 3,
#  'clear': 4,
#  'meaning': 5,
#  'text': 7,
#  '(later)': 1,
#  'readers': 1,
#  'seeks': 1,
#  'resolve': 1,
#  'reason': 1,
#  'become': 5,
#  'unacceptable;': 1,
#  'yet': 3,
#  'radical': 1,
#  'strategy': 1,
#  'conserving': 1,
#  'old': 4,
#  'precious': 1,
#  'repudiate': 1,
#  'revamping': 1,
#  'actually': 3,
#  'erasing': 1,
#  'rewriting': 1,
#  'altering': 1,
#  'cant': 1,
#  'admit': 1,
#  'claims': 1,
#  'making': 4,
#  'intelligible': 2,
#  'disclosing': 1,
#  'far': 1,
#  'interpreters': 6,
#  'alter': 1,
#  '(another': 1,
#  'notorious': 1,
#  'example': 6,
#  'rabbinic': 1,
#  'christian': 1,
#  'clearly': 1,
#  'erotic': 1,
#  '4': 2,
#  'song': 1,
#  'songs)': 1,
#  'claim': 1,
#  'reading': 1,
#  'already': 3,
#  'time': 6,
#  'complex': 2,
#  'zeal': 2,
#  'often': 2,
#  'prompted': 1,
#  'piety': 1,
#  'toward': 1,
#  'troublesome': 1,
#  '(which': 1,
#  'conceal': 1,
#  'aggression)': 1,
#  'open': 1,
#  'aggressiveness': 1,
#  'overt': 1,
#  'contempt': 1,
#  'style': 3,
#  'insistent': 1,
#  'respectful;': 1,
#  'erected': 1,
#  'top': 1,
#  'excavates': 2,
#  'destroys;': 1,
#  'digs': 1,
#  'behind': 1,
#  'find': 4,
#  'sub-text': 1,
#  'celebrated': 1,
#  'influential': 1,
#  'doctrines': 1,
#  'marx': 3,
#  'freud': 3,
#  'amount': 2,
#  'systems': 1,
#  'hermeneutics': 2,
#  'aggressive': 1,
#  'impious': 1,
#  'theories': 1,
#  'observable': 1,
#  'phenomena': 1,
#  'bracketed': 1,
#  'freuds': 1,
#  'phrase': 1,
#  'manifest': 2,
#  'probed': 1,
#  'pushed': 1,
#  'aside': 1,
#  'meaningthe': 1,
#  'latent': 1,
#  'beneath': 1,
#  'social': 3,
#  'events': 3,
#  'revolutions': 1,
#  'wars;': 1,
#  'lives': 1,
#  '(like': 2,
#  'neurotic': 1,
#  'symptoms': 1,
#  'slips': 1,
#  'tongue)': 1,
#  'well': 2,
#  'dream': 1,
#  'art)all': 1,
#  'treated': 1,
#  'occasions': 1,
#  'understand': 1,
#  'restate': 1,
#  'phenomenon': 1,
#  'effect': 1,
#  'equivalent': 3,
#  '(as': 1,
#  'assume)': 1,
#  'absolute': 1,
#  'gesture': 1,
#  'situated': 1,
#  'timeless': 1,
#  'realm': 1,
#  'capabilities': 1,
#  'evaluated': 1,
#  'human': 1,
#  'cultural': 2,
#  'contexts': 2,
#  'liberating': 3,
#  'revising': 1,
#  'transvaluing': 1,
#  'escaping': 1,
#  'dead': 1,
#  'reactionary': 2,
#  'impertinent': 1,
#  'cowardly': 1,
#  'stifling': 2,
#  'largely': 1,
#  'fumes': 1,
#  'automobile': 1,
#  'heavy': 1,
#  'industry': 1,
#  'befoul': 1,
#  'urban': 2,
#  'atmosphere': 1,
#  'effusion': 1,
#  'poisons': 1,
#  'sensibilities': 1,
#  'whose': 4,
#  'dilemma': 1,
#  'hypertrophy': 1,
#  'intellect': 3,
#  'expense': 2,
#  'energy': 1,
#  'sensual': 2,
#  'capability': 1,
#  'revenge': 2,
#  'impoverish': 1,
#  'deplete': 1,
#  'worldin': 1,
#  'shadow': 1,
#  'meanings': 3,
#  'turn': 1,
#  '(this': 1,
#  'world!': 1,
#  'other.)': 1,
#  '5': 2,
#  'depleted': 1,
#  'impoverished': 1,
#  'enough': 1,
#  'duplicates': 1,
#  'immediately': 1,
#  'instances': 1,
#  'amounts': 1,
#  'philistine': 1,
#  'refusal': 1,
#  'leave': 1,
#  'alone': 2,
#  'real': 2,
#  'capacity': 1,
#  'make': 2,
#  'nervous': 1,
#  'reducing': 1,
#  'interpreting': 1,
#  'tames': 1,
#  'manageable': 2,
#  'comformable': 1,
#  'rife': 1,
#  'literature': 2,
#  'decades': 1,
#  'literary': 2,
#  'understood': 3,
#  'translate': 1,
#  'poem': 1,
#  'play': 3,
#  'novel': 3,
#  'sometimes': 1,
#  'writer': 1,
#  'will': 3,
#  'uneasy': 1,
#  'naked': 1,
#  'install': 1,
#  'itselfalbeit': 1,
#  'little': 2,
#  'shyness': 1,
#  'touch': 1,
#  'taste': 2,
#  'ironythe': 1,
#  'explicit': 2,
#  'thomas': 1,
#  'mann': 1,
#  'overcooperative': 1,
#  'author': 4,
#  'stubborn': 1,
#  'authors': 1,
#  'critic': 2,
#  'happy': 2,
#  'perform': 1,
#  'job': 1,
#  'kafka': 4,
#  'subjected': 1,
#  'mass': 2,
#  'ravishment': 1,
#  'three': 1,
#  'armies': 1,
#  'read': 4,
#  'studies': 1,
#  'frustrations': 1,
#  'insanity': 1,
#  'bureaucracy': 1,
#  'ultimate': 1,
#  'issuance': 1,
#  'totalitarian': 1,
#  'state': 1,
#  'psychoanalytic': 1,
#  'desperate': 1,
#  'revelations': 1,
#  'kafkas': 1,
#  'fear': 1,
#  'father': 1,
#  'castration': 1,
#  'anxieties': 1,
#  'impotence': 1,
#  'thralldom': 1,
#  'dreams': 1,
#  'explain': 1,
#  'castle': 1,
#  'gain': 1,
#  'access': 1,
#  'heaven': 1,
#  'joseph': 1,
#  'trial': 1,
#  'judged': 1,
#  'inexorable': 1,
#  'mysterious': 2,
#  'justice': 1,
#  'god': 2,
#  'oeuvre': 1,
#  'attracted': 1,
#  'leeches': 1,
#  'samuel': 1,
#  'beckett': 1,
#  'becketts': 1,
#  'delicate': 2,
#  'dramas': 1,
#  'withdrawn': 1,
#  'consciousnesspared': 1,
#  'essentials': 1,
#  'cut': 2,
#  'represented': 2,
#  'physically': 1,
#  'immobilizedare': 1,
#  'mans': 1,
#  'alienation': 1,
#  'psychopathology': 1,
#  'proust': 1,
#  'joyce': 1,
#  'faulkner': 1,
#  'rilke': 1,
#  'lawrence': 1,
#  'gideone': 1,
#  'go': 2,
#  'citing': 1,
#  'author;': 1,
#  'list': 1,
#  'endless': 1,
#  'around': 1,
#  'thick': 1,
#  'encrustations': 1,
#  'taken': 3,
#  'hold': 2,
#  'noted': 1,
#  'simply': 3,
#  'compliment': 1,
#  'mediocrity': 1,
#  'pays': 1,
#  'genius': 1,
#  'understanding': 1,
#  'applied': 3,
#  'every': 2,
#  'quality': 2,
#  'notes': 1,
#  'elia': 1,
#  'kazan': 3,
#  'published': 1,
#  'production': 1,
#  'streetcar': 2,
#  'named': 3,
#  'desire': 1,
#  'direct': 2,
#  'discover': 1,
#  'stanley': 2,
#  '6': 2,
#  'kowalski': 2,
#  'vengeful': 1,
#  'barbarism': 1,
#  'engulfing': 1,
#  'blanche': 2,
#  'du': 2,
#  'bois': 2,
#  'civilization': 2,
#  'poetry': 6,
#  'apparel': 1,
#  'dim': 1,
#  'lighting': 1,
#  'refined': 1,
#  'feelings': 1,
#  'worse': 1,
#  'wear': 1,
#  'sure': 1,
#  'tennessee': 2,
#  'williams': 3,
#  'forceful': 1,
#  'psychological': 1,
#  'melodrama': 1,
#  'became': 1,
#  'intelligible:': 1,
#  'decline': 1,
#  'apparently': 1,
#  'handsome': 1,
#  'brute': 2,
#  'faded': 1,
#  'mangy': 1,
#  'belle': 1,
#  'doesnt': 1,
#  'matter': 1,
#  'intend': 2,
#  'perhaps': 4,
#  'thinks': 2,
#  'cocteau': 1,
#  'blood': 1,
#  'poet': 1,
#  'orpheus': 1,
#  'wanted': 1,
#  'readings': 1,
#  'films': 10,
#  'freudian': 2,
#  'symbolism': 1,
#  'critique': 1,
#  'merit': 1,
#  'certainly': 1,
#  'lies': 1,
#  'elsewhere': 1,
#  'precisely': 1,
#  'extent': 2,
#  'plays': 2,
#  'cocteaus': 1,
#  'portentous': 1,
#  'defective': 1,
#  'false': 1,
#  'contrived': 1,
#  'lacking': 1,
#  'conviction': 1,
#  'interviews': 1,
#  'resnais': 1,
#  'robbe-grillet': 2,
#  'consciously': 1,
#  'designed': 1,
#  'last': 1,
#  'year': 1,
#  'marienbad': 3,
#  'accommodate': 1,
#  'multiplicity': 1,
#  'equally': 2,
#  'plausible': 1,
#  'temptation': 1,
#  'resisted': 1,
#  'matters': 1,
#  'pure': 1,
#  'untranslatable': 1,
#  'sensuous': 2,
#  'immediacy': 1,
#  'images': 2,
#  'rigorous': 1,
#  'narrow': 1,
#  'solutions': 1,
#  'cinematic': 1,
#  'ingmar': 1,
#  'bergman': 1,
#  'meant': 2,
#  'tank': 3,
#  'rumbling': 1,
#  'empty': 1,
#  'night': 1,
#  'street': 1,
#  'silence': 4,
#  'phallic': 1,
#  'symbol': 1,
#  'foolish': 1,
#  '(never': 1,
#  'trust': 2,
#  'teller': 1,
#  'tale': 1,
#  'lawrence.)': 1,
#  'object': 1,
#  'immediate': 1,
#  'sensory': 4,
#  'abrupt': 1,
#  'armored': 1,
#  'happenings': 1,
#  'going': 1,
#  'inside': 1,
#  'hotel': 1,
#  'sequence': 1,
#  'striking': 1,
#  'moment': 1,
#  'film': 5,
#  'reach': 1,
#  'expressing': 1,
#  'lack': 1,
#  'response': 1,
#  'screen': 1,
#  'type': 1,
#  'indicates': 1,
#  'dissatisfaction': 1,
#  '(conscious': 1,
#  'unconscious)': 1,
#  'wish': 1,
#  'replace': 1,
#  'based': 2,
#  'highly': 1,
#  'composed': 1,
#  'items': 1,
#  'violates': 1,
#  'article': 1,
#  'use': 1,
#  'arrangement': 1,
#  'mental': 1,
#  'scheme': 1,
#  'categories': 1,
#  '7': 2,
#  'prevail': 1,
#  'great': 3,
#  'deal': 2,
#  'todays': 1,
#  'motivated': 1,
#  'flight': 2,
#  'avoid': 1,
#  'parody': 1,
#  '(merely)': 1,
#  'non-art': 1,
#  'attempt': 1,
#  'content;': 1,
#  'pop': 1,
#  'opposite': 1,
#  'result;': 1,
#  'using': 1,
#  'blatant': 1,
#  'ends': 1,
#  'uninterpretable': 1,
#  'starting': 1,
#  'experiments': 2,
#  'french': 1,
#  '(including': 1,
#  'movement': 1,
#  'misleadingly': 1,
#  'called': 1,
#  'symbolism)': 1,
#  'poems': 1,
#  'reinstate': 1,
#  'magic': 1,
#  'word': 1,
#  'escaped': 1,
#  'rough': 1,
#  'grip': 1,
#  'recent': 1,
#  'revolution': 2,
#  'poetrythe': 1,
#  'deposed': 1,
#  'eliot': 1,
#  'elevated': 1,
#  'poundrepresents': 1,
#  'turning': 1,
#  'impatience': 1,
#  'made': 1,
#  'prey': 1,
#  'speaking': 1,
#  'america': 1,
#  'runs': 1,
#  'rampant': 1,
#  'feeble': 1,
#  'negligible': 1,
#  'avant-garde:': 1,
#  'fiction': 2,
#  'drama': 4,
#  'american': 1,
#  'novelists': 1,
#  'playwrights': 1,
#  'either': 1,
#  'journalists': 1,
#  'gentlemen': 1,
#  'sociologists': 1,
#  'psychologists': 1,
#  'writing': 1,
#  'program': 1,
#  'music': 2,
#  'rudimentary': 1,
#  'uninspired': 1,
#  'stagnant': 1,
#  'might': 2,
#  'isnt': 1,
#  'information': 1,
#  'news': 1,
#  'peculiarly': 1,
#  'handier': 1,
#  'exposed': 1,
#  'novels': 1,
#  '(in': 1,
#  'america)': 1,
#  'unlike': 2,
#  'reflect': 1,
#  'interesting': 1,
#  'concern': 1,
#  'changes': 1,
#  'remain': 1,
#  'prone': 1,
#  'assault': 1,
#  'programmatic': 1,
#  'avant-gardismwhich': 1,
#  'mostly': 1,
#  'contentis': 1,
#  'infestation': 1,
#  'least': 1,
#  'hope': 1,
#  'commit': 1,
#  'perpetually': 1,
#  'run': 1,
#  '(it': 1,
#  'perpetuates': 1,
#  'distinction': 1,
#  'ultimately': 1,
#  'illusion.)': 1,
#  'ideally': 1,
#  'possible': 2,
#  'elude': 1,
#  'surface': 2,
#  'unified': 1,
#  'clean': 1,
#  'momentum': 1,
#  'rapid': 1,
#  'address': 1,
#  'bejust': 1,
#  'now?': 1,
#  'happen': 1,
#  'believe': 1,
#  'cinema': 4,
#  'alive': 2,
#  'exciting': 1,
#  'important': 2,
#  'right': 1,
#  'tells': 1,
#  'particular': 1,
#  'latitude': 1,
#  'mistakes': 1,
#  '8': 2,
#  'bergmanthough': 1,
#  'crammed': 1,
#  'lame': 1,
#  'messages': 1,
#  'spirit': 1,
#  'thereby': 1,
#  'inviting': 1,
#  'interpretationsstill': 1,
#  'triumph': 1,
#  'pretentious': 1,
#  'intentions': 1,
#  'director': 1,
#  'winter': 1,
#  'light': 2,
#  'beauty': 1,
#  'visual': 2,
#  'sophistication': 1,
#  'subvert': 1,
#  'callow': 1,
#  'pseudointellectuality': 1,
#  'dialogue': 1,
#  'remarkable': 1,
#  'instance': 1,
#  'sort': 2,
#  'd': 1,
#  'w': 1,
#  'griffith.)': 1,
#  'directness': 1,
#  'entirely': 1,
#  'frees': 1,
#  'itch': 1,
#  'hollywood': 1,
#  'cukor': 1,
#  'walsh': 1,
#  'hawks': 1,
#  'countless': 1,
#  ...}

# %%
list(wordCounts_dict.items())[:10]
# Out:
# [('content', 28),
#  ('glimpse', 1),
#  ('something', 9),
#  ('encounter', 1),
#  ('flash', 1),
#  ('tinyvery', 1),
#  ('tiny', 1),
#  ('william', 1),
#  ('de', 1),
#  ('kooning', 1)]

# %%
import operator
sorted_dict=sorted(wordCounts_dict.items(),key=operator.itemgetter(1))

# %%
#display top 10 frequent words.
sorted(wordCounts_dict.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('art', 71),
#  ('interpretation', 42),
#  ('content', 28),
#  ('work', 24),
#  ('form', 17),
#  ('works', 14),
#  ('theory', 13),
#  ('modern', 12),
#  ('may', 12),
#  ('now', 12)]

# %% [markdown]
# Generating WordCloud

# %%
# Generate and plot word cloud.
wc = WordCloud()

text = "".join(lines)       # combine  list of strings into one single string

wc.generate(text)   

fig = plt.figure(figsize = (10,8))
plt.imshow(wc)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
